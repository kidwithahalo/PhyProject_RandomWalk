# %%
'''Random walk in 1D
Body is initially resting at x = 0 and it will move
either in postive or negative x direction
'''


import random

def random_walk(n):

    x = 0
    # particle postioned at x = 0
    for i in range(n):
        step = random.choice([-1,1])
        # steps being randomly assigned either +ve or -ve

        if step == -1:
            x = x-1
        else:
            x = x+1
    return (x)


number_of_walk = 100000
walk_length = 20
position = []
# length of walk defines how much steps can body take

for i in range(number_of_walk):
    walk = random_walk(walk_length)
#     (walk, "Distance from origin = ", abs(walk))
    position.append(walk)

print(f'\nWalk length = 20, total walk = 100000\n\n Positions:\n {position}')
# Out:
# Walk length = 20, total walk = 100000
#
#  Positions:
#  [0, 4, 6, 4, -8, -6, 0, 0, -2, -6, -6, 0, -10, 4, -4, 0, 4, -6, 8, 4, 4, 0, 2, -4, 6, -6, -2, 2, -4, -6, 0, -10, 8, -6, 0, -4, -8, -2, -4, -2, -4, 2, 6, 4, 0, 4, -6, 2, 2, 2, -4, 8, -4, 2, 2, -2, 6, 4, 0, -4, 0, 10, -2, -2, 0, 2, 0, -2, -6, 6, 0, -6, 2, -2, 6, 0, -6, 4, 4, 0, 4, -2, 8, 10, 2, 2, -2, 8, 4, 2, 0, -6, 2, -4, -4, 6, 2, 4, 0, 0, 4, -2, -2, -2, 0, 0, 0, 0, 2, 0, 10, -4, -4, -6, 4, -2, -2, 2, -4, -2, -8, 2, 0, 2, -2, -2, 4, -4, -4, 4, 2, -8, 6, 8, -2, -2, 0, 12, -2, 2, -2, 0, -4, 2, -4, 2, 0, 6, 10, 8, -8, -2, 2, -2, 8, -10, -2, 6, -2, 14, 6, 0, 0, 0, 0, 4, 4, -4, 6, 8, -2, 6, 2, -2, -4, 2, -10, -2, -8, 6, 4, 4, 8, -2, 6, 4, 2, 4, -2, 0, 8, 0, -8, 2, -4, -4, -4, 0, -2, 0, 2, 0, -2, 2, -8, -2, 6, -2, -6, 0, 0, 2, -10, 4, 2, 8, -6, 4, 0, 2, 0, 0, 0, 4, -4, -2, -2, 0, -2, 4, -10, 4, 6, -2, 2, 6, 2, 4, -2, -6, 4, 0, -8, 6, 2, 2, -8, 0, 0, 2, 0, 0, 6, -2, -4, -8, 0, -4, -4, -2, 4, -2, 4, 2, -4, -6, 4, 0, 6, 4, 6, 2, 8, -2, -2, 0, -4, -2, -2, 4, 0, 4, 12, 0, 0, 0, 0, 0, 2, 2, -6, 10, 0, 4, 4, 4, 4, -2, 0, 0, 2, -4, 2, 2, 2, 4, 0, 4, 2, -2, -2, 2, -4, 4, 4, 2, 2, -8, -2, -6, -6, 12, 2, 2, 4, 4, 2, 4, -8, -2, -8, -2, 2, 2, 6, 2, 4, -4, -4, 2, -2, -4, -4, 6, 2, -8, 0, 4, 4, 0, -2, 0, 0, 2, 0, 0, -4, 
8, -6, -6, 0, 2, 0, -4, -2, 6, 2, 0, -4, 0, 8, 2, 0, 0, 8, 0, 4, 6, 2, 2, -2, 12, 4, 0, 0, 0, -6, -4, 0, 2, 4, 6, -2, 2, 0, -2, 4, -4, 4, -2, 4, 4, 4, -4, 4, 6, -2, 0, -6, -4, -14, -8, -2, 6, -2, -2, 6, 8, -8, -4, -4, 8, -2, 0, -10, -4, 0, -2, 0, 0, -2, -8, 4, 4, 8, 0, 6, 6, 0, 4, 6, -2, -4, 0, 4, 6, 4, 6, 4, 0, 4, -2, -2, -2, 8, 6, 0, 2, -4, 6, 2, 2, 2, -4, -6, 6, -4, 0, 4, 4, 4, -2, 6, -6, 0, 2, 4, 4, -2, 4, -2, -4, -6, -2, -4, 6, -2, 6, 2, 0, 0, 2, 2, 4, 0, 2, -2, 8, 2, -4, 2, 0, -2, -4, -4, -2, 0, -8, -2, -4, -4, 6, -4, 4, 6, 0, 12, -4, 2, 2, 0, -6, -4, 0, 0, 2, -2, 2, -4, 6, -2, 2, -2, -6, 4, 6, 2, 10, 2, -4, -2, -2, 2, 4, 2, -6, -10, 8, 4, 2, -6, 0, -2, -2, 8, 8, 2, -4, -2, -10, 0, 6, 4, -4, 6, -2, -4, 4, 2, 0, 0, 2, 0, -2, -8, -2, -6, 8, 0, -8, 2, 4, 2, 2, 4, 4, 4, -2, -4, -2, -2, -10, 2, 4, -6, 0, -2, 0, 0, 12, 2, 0, 2, -12, 2, 8, 4, 4, -4, 6, 0, 4, -4, -6, 4, 4, -4, -4, -2, -4, -4, 6, 4, 0, 0, 2, -2, -4, 2, 0, -8, -4, -2, 0, 10, -2, 0, 6, 2, 10, -4, 8, 2, -4, -4, 8, -2, -6, 0, 6, -4, 0, -2, 2, 2, 2, 2, -2, -4, 4, 0, -4, 2, -2, 2, -2, 6, -8, -2, 4, 2, 0, 4, 4, -4, -10, 2, -2, -6, -2, 0, 0, -4, -2, -4, 2, 6, 6, -8, -4, 4, 2, -4, 0, 4, -2, -10, 4, -2, -8, 2, 8, -6, 4, ...

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

plt.hist(position,50, fc = 'r')
plt.xlim(-15,15)
plt.title('Position distribution of walker -->100000 walks of length 20 ')
plt.show()

# %%
sns.distplot(np.random.binomial(n=20,p=0.5, size = 100000 ), hist = True, kde=False, label ='binomial', color ='g')
plt.title("Binomial distribution of 10000 walks of length 20")
plt.show()
# Out:
# /Users/pankajksingh/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(np.random.binomial(n=30,p=0.5, size = 100000 ), hist = True, kde=False, label ='binomial', color ='k')
plt.title("Binomial distribution of 10000 walks of length 30")
plt.show()

# %%
sns.distplot(np.random.binomial(n=50,p=0.5, size = 100000 ), hist = True, kde=False, label ='binomial', color ='blue')
plt.title("Binomial distribution of 10000 walks of length 50")
plt.show()
