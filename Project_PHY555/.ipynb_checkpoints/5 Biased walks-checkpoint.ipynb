# %% [markdown]
# We are extending our study for a biased walker when p != q
#
# We are taking , p = 0.8 and hence likewise q = 0.2

# %%
from scipy import stats

# %% [markdown]
# ## N = 10

# %%
'''Random walk in 1D
Body is initially resting at x = 0 and it will move
either in postive or negative x direction
'''


import random

def random_walk(n):

    x = 0
    # particle postioned at x = 0
    for i in range(n):
        step = random.random()
        # steps being randomly assigned either +ve or -ve

        if step <= 0.2:
            x = x-1
        else:
            x = x+1
    return (x)


number_of_walk = 300000
walk_length = 10
position = []
# length of walk defines how much steps can body take

for i in range(number_of_walk):
    walk = random_walk(walk_length)
#     (walk, "Distance from origin = ", abs(walk))
    position.append(walk)

print(stats.describe(position))
# Out:
# DescribeResult(nobs=300000, minmax=(-6, 10), mean=6.004613333333333, variance=6.386880006755578, skewness=-0.472159819810692, kurtosis=0.005320828618794238)

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

#create range of x-values from -4 to 4 in increments of .001
x = np.arange(np.min(position), np.max(position), 0.001)

#create range of y-values that correspond to normal pdf with mean and sd 
y = norm.pdf(x,6.0046,np.sqrt(6.3868))

#define plot 
fig = plt.figure(figsize=(9,6))
plt.plot(x,y, label = "Theoretical", linestyle = 'dashed', color = 'b')
plt.hist(position,20, density = True, fc = 'brown', alpha = 1, label = "Simulation")

#choose plot style and display the bell curve 
plt.style.use('seaborn-pastel')
plt.legend(fontsize = 20)
plt.title("N = 10")
plt.savefig("N_10_biashed.pdf")
plt.figure()
plt.show()

# %% [markdown]
# ## N = 20

# %%
'''Random walk in 1D
Body is initially resting at x = 0 and it will move
either in postive or negative x direction
'''


import random

def random_walk(n):

    x = 0
    # particle postioned at x = 0
    for i in range(n):
        step = random.random()
        # steps being randomly assigned either +ve or -ve

        if step <= 0.2:
            x = x-1
        else:
            x = x+1
    return (x)


number_of_walk = 300000
walk_length = 20
position = []
# length of walk defines how much steps can body take

for i in range(number_of_walk):
    walk = random_walk(walk_length)
#     (walk, "Distance from origin = ", abs(walk))
    position.append(walk)

print(stats.describe(position))
# Out:
# DescribeResult(nobs=300000, minmax=(-6, 20), mean=11.994646666666666, variance=12.826534096935879, skewness=-0.3376609061895982, kurtosis=0.020186192117989332)

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

#create range of x-values from -4 to 4 in increments of .001
x = np.arange(np.min(position), np.max(position), 0.001)

#create range of y-values that correspond to normal pdf with mean and sd 
y = norm.pdf(x,11.9946,np.sqrt(12.8265))

#define plot 
fig = plt.figure(figsize=(9,6))
plt.plot(x,y, label = "Theoretical", linestyle = 'dashed', color = 'b')
plt.hist(position,40, density = True, fc = 'purple', alpha = 1, label = "Simulation")

#choose plot style and display the bell curve 
plt.style.use('seaborn-bright')
plt.legend(fontsize = 20)
plt.title("N = 20")
plt.figure()
plt.savefig("N_20_biashed.pdf")
plt.show()

# %% [markdown]
# ## N = 30

# %%
'''Random walk in 1D
Body is initially resting at x = 0 and it will move
either in postive or negative x direction
'''


import random

def random_walk(n):

    x = 0
    # particle postioned at x = 0
    for i in range(n):
        step = random.random()
        # steps being randomly assigned either +ve or -ve

        if step <= 0.2:
            x = x-1
        else:
            x = x+1
    return (x)


number_of_walk = 300000
walk_length = 30
position = []
# length of walk defines how much steps can body take

for i in range(number_of_walk):
    walk = random_walk(walk_length)
#     (walk, "Distance from origin = ", abs(walk))
    position.append(walk)



print(stats.describe(position))
# Out:
# DescribeResult(nobs=300000, minmax=(-6, 30), mean=18.018906666666666, variance=19.156079724887974, skewness=-0.2756813299901338, kurtosis=0.01934801310312695)

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

#create range of x-values from -4 to 4 in increments of .001
x = np.arange(np.min(position), np.max(position), 0.001)

#create range of y-values that correspond to normal pdf with mean and sd 
y = norm.pdf(x,np.mean(position),np.std(position))

#define plot 
fig = plt.figure(figsize=(9,6))
plt.plot(x,y, label = "Theoretical", linestyle = 'dashed')
plt.hist(position,50, density = True, fc = 'lightcoral', alpha = 1, label = "Simulation")

#choose plot style and display the bell curve 
plt.style.use('seaborn-bright')
plt.legend(fontsize = 20)
plt.title("N = 30")
plt.figure()
plt.savefig("N_30_biashed.pdf")
plt.show()

# %% [markdown]
# ## N = 50

# %%
'''Random walk in 1D
Body is initially resting at x = 0 and it will move
either in postive or negative x direction
'''


import random

def random_walk(n):

    x = 0
    # particle postioned at x = 0
    for i in range(n):
        step = random.random()
        # steps being randomly assigned either +ve or -ve

        if step <= 0.2:
            x = x-1
        else:
            x = x+1
    return (x)


number_of_walk = 300000
walk_length = 50
position = []
# length of walk defines how much steps can body take

for i in range(number_of_walk):
    walk = random_walk(walk_length)
#     (walk, "Distance from origin = ", abs(walk))
    position.append(walk)



print(stats.describe(position))
# Out:
# DescribeResult(nobs=300000, minmax=(0, 50), mean=29.983293333333332, variance=32.074707802981564, skewness=-0.2180831878122417, kurtosis=0.005633209876366951)

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm


x = np.arange(np.min(position), np.max(position), 0.001)

#create range of y-values that correspond to normal pdf with mean and sd 
y = norm.pdf(x,np.mean(position),np.std(position))

#define plot 
fig = plt.figure(figsize=(9,6))
plt.plot(x,y, label = "Theoretical", linestyle = 'dashed', color = 'blue')
plt.hist(position,50, density = True, fc = 'plum', alpha = 1, label = "Simulation")

#choose plot style and display the bell curve 
plt.style.use('seaborn-deep')
plt.legend(fontsize = 20)
plt.title("N = 50")
plt.figure()
plt.savefig("N_50_biashed.pdf")
plt.show()

# %% [markdown]
# ## N = 100

# %%
'''Random walk in 1D
Body is initially resting at x = 0 and it will move
either in postive or negative x direction
'''


import random

def random_walk(n):

    x = 0
    # particle postioned at x = 0
    for i in range(n):
        step = random.random()
        # steps being randomly assigned either +ve or -ve

        if step <= 0.2:
            x = x-1
        else:
            x = x+1
    return (x)


number_of_walk = 300000
walk_length = 100
position = []
# length of walk defines how much steps can body take

for i in range(number_of_walk):
    walk = random_walk(walk_length)
#     (walk, "Distance from origin = ", abs(walk))
    position.append(walk)



print(stats.describe(position))
# Out:
# DescribeResult(nobs=300000, minmax=(18, 92), mean=60.00408, variance=64.11243706172354, skewness=-0.15046082473336714, kurtosis=0.003467365825600144)

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm


x = np.arange(np.min(position), np.max(position), 0.001)

#create range of y-values that correspond to normal pdf with mean and sd 
y = norm.pdf(x,np.mean(position),np.std(position))

#define plot 
fig = plt.figure(figsize=(9,6))
plt.plot(x,y, label = "Theoretical", color = 'blue', linestyle = 'dashed')
plt.hist(position,70, density = True, fc = 'springgreen', alpha = 1, label = "Simulation")

#choose plot style and display the bell curve 
plt.style.use('seaborn-pastel')
plt.legend(fontsize = 20)
plt.title("N = 100")
plt.figure()
plt.savefig("N_100_biashed.pdf")
plt.show()

# %% [markdown]
# ## Some Higher N

# %%
'''Random walk in 1D
Body is initially resting at x = 0 and it will move
either in postive or negative x direction
'''


import random

def random_walk(n):

    x = 0
    # particle postioned at x = 0
    for i in range(n):
        step = random.random()
        # steps being randomly assigned either +ve or -ve

        if step <= 0.2:
            x = x-1
        else:
            x = x+1
    return (x)


number_of_walk = 10000
walk_length = 8000
position = []
# length of walk defines how much steps can body take

for i in range(number_of_walk):
    walk = random_walk(walk_length)
#     (walk, "Distance from origin = ", abs(walk))
    position.append(walk)



print(stats.describe(position))
# Out:
# DescribeResult(nobs=10000, minmax=(4488, 5088), mean=4800.6712, variance=5079.243014861486, skewness=-0.018910913539709095, kurtosis=0.008302474842889485)

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm


x = np.arange(np.min(position), np.max(position), 0.0001)

#create range of y-values that correspond to normal pdf with mean and sd 
y = norm.pdf(x,np.mean(position),np.std(position))

#define plot 
fig = plt.figure(figsize=(9,6))
plt.plot(x,y, label = "Theoretical", color = 'blue', linestyle = 'dashed')
plt.hist(position,150, density = True, fc = 'springgreen', alpha = 1, label = "Simulation")

#choose plot style and display the bell curve 
plt.style.use('seaborn-pastel')
plt.legend(fontsize = 20)
plt.title("N = 8000", fontsize = 20)
plt.figure()
plt.show()
