# %% [markdown]
# ><h3>Walker in presence of constant resetting probability $0 \leq r < 1$

# %% [markdown]
# The position of $x_n$ evolves by rule as <br>
# $
# x_n = \begin{cases}
# 0, \hspace{30mm} \text{   with proba. r   }  \\
# x_{n-1} + \eta_{n} , \hspace{15mm} \text{ with proba. 1 - r  }
# \end{cases}
# $

# %% [markdown]
# <h3><font color='Blue'>Symmetric walkers with $r = 0.5$ for constant resetting

# %% [markdown]
# # N = 100

# %%
from scipy import stats
import random
import matplotlib.pyplot as plt

global x
x = 0 

def random_walk(n):
    x_1 = 0
    # particle postioned at x = 0
    for i in range(n):
        step = round(random.random(),2)
        # steps being randomly assigned either +ve or -ve
        if step <= 0.50:
            x_1 = x
        elif step > 0.50:
            zeta = np.random.choice([-1,1])
            if zeta == -1:
                x_1 = x_1 - 1 
            else:
                x_1 = x_1 + 1
    return (x_1)


number_of_walk = 100
walk_length = 100
position = []
# length of walk defines how much steps can body take

for i in range(number_of_walk):
    walk = random_walk(walk_length)
#     (walk, "Distance from origin = ", abs(walk))
    position.append(walk)

print(stats.describe(position))
# Out:
# DescribeResult(nobs=100, minmax=(-3, 4), mean=0.06, variance=0.8448484848484848, skewness=0.43040866305743564, kurtosis=3.379543538029691)

# %%
from scipy import stats
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

df = pd.DataFrame(position, columns=['position'])

fig,ax1 = plt.subplots(dpi=200)
sns.kdeplot(data=df,x='position',linestyle='--',linewidth= 1,ax=ax1, color='blue')

ax2 = ax1.twinx()
# ax1.text(15,0.016,s=r'$\mu \Rightarrow N(p-q)$ = 1600',bbox=dict(facecolor='red', alpha=0.5))
sns.histplot(data=df, x='position',discrete=True,ax=ax2, alpha = 0.6)
plt.title("N = 100", color= 'r')
# plt.savefig('N=100')
plt.show()

# %% [markdown]
# ## N = 500

# %%
from scipy import stats
import random
import matplotlib.pyplot as plt

global x
x = 0 

def random_walk(n):
    x_1 = 0
    # particle postioned at x = 0
    for i in range(n):
        step = round(random.random(),2)
        # steps being randomly assigned either +ve or -ve
        if step <= 0.50:
            x_1 = x
        elif step > 0.50:
            zeta = np.random.choice([-1,1])
            if zeta == -1:
                x_1 = x_1 - 1 
            else:
                x_1 = x_1 + 1
    return (x_1)


number_of_walk = 100
walk_length = 500
position = []
# length of walk defines how much steps can body take

for i in range(number_of_walk):
    walk = random_walk(walk_length)
#     (walk, "Distance from origin = ", abs(walk))
    position.append(walk)

print(stats.describe(position))
# Out:
# DescribeResult(nobs=100, minmax=(-3, 3), mean=0.05, variance=0.9166666666666666, skewness=0.039039462229200975, kurtosis=1.8686792796484744)

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

df = pd.DataFrame(position, columns=['position'])

fig,ax1 = plt.subplots(dpi=200)
sns.kdeplot(data=df,x='position',linestyle='--',linewidth= 1,ax=ax1, color='blue')

ax2 = ax1.twinx()
# ax1.text(15,0.016,s=r'$\mu \Rightarrow N(p-q)$ = 1600',bbox=dict(facecolor='red', alpha=0.5))
sns.histplot(data=df, x='position',discrete=True,ax=ax2, alpha = 0.6)
plt.title("N = 500", color= 'r')
# plt.savefig('N=500')
plt.show()

# %% [markdown]
# ## N = 1000

# %%
from scipy import stats
import random
import matplotlib.pyplot as plt

global x
x = 0 

def random_walk(n):
    x_1 = 0
    # particle postioned at x = 0
    for i in range(n):
        step = round(random.random(),2)
        # steps being randomly assigned either +ve or -ve
        if step <= 0.50:
            x_1 = x
        elif step > 0.50:
            zeta = np.random.choice([-1,1])
            if zeta == -1:
                x_1 = x_1 - 1 
            else:
                x_1 = x_1 + 1
    return (x_1)


number_of_walk = 100
walk_length = 1000
position = []
# length of walk defines how much steps can body take

for i in range(number_of_walk):
    walk = random_walk(walk_length)
#     (walk, "Distance from origin = ", abs(walk))
    position.append(walk)

print(stats.describe(position))
# Out:
# DescribeResult(nobs=100, minmax=(-2, 4), mean=0.18, variance=1.341010101010101, skewness=1.0572557450156643, kurtosis=2.002170707951998)

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

df = pd.DataFrame(position, columns=['position'])

fig,ax1 = plt.subplots(dpi=200)
sns.kdeplot(data=df,x='position',linestyle='--',linewidth= 1,ax=ax1, color='blue')

ax2 = ax1.twinx()
# ax1.text(15,0.016,s=r'$\mu \Rightarrow N(p-q)$ = 1600',bbox=dict(facecolor='red', alpha=0.5))
sns.histplot(data=df, x='position',discrete=True,ax=ax2, alpha = 0.6)
plt.title("N = 1000", color= 'r')
# plt.savefig('N=500')
plt.show()

# %% [markdown]
# ## N = 5000

# %%
from scipy import stats
import random
import matplotlib.pyplot as plt

global x
x = 0 

def random_walk(n):
    x_1 = 0
    # particle postioned at x = 0
    for i in range(n):
        step = round(random.random(),2)
        # steps being randomly assigned either +ve or -ve
        if step <= 0.50:
            x_1 = x
        elif step > 0.50:
            zeta = np.random.choice([-1,1])
            if zeta == -1:
                x_1 = x_1 - 1 
            else:
                x_1 = x_1 + 1
    return (x_1)


number_of_walk = 100
walk_length = 5000
position = []
# length of walk defines how much steps can body take

for i in range(number_of_walk):
    walk = random_walk(walk_length)
#     (walk, "Distance from origin = ", abs(walk))
    position.append(walk)

print(stats.describe(position))
# Out:
# DescribeResult(nobs=100, minmax=(-3, 3), mean=0.02, variance=0.9086868686868684, skewness=-0.2507882190616378, kurtosis=1.8375824757646377)

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

df = pd.DataFrame(position, columns=['position'])

fig,ax1 = plt.subplots(dpi=200)
sns.kdeplot(data=df,x='position',linestyle='--',linewidth= 1,ax=ax1, color='blue')

ax2 = ax1.twinx()
# ax1.text(15,0.016,s=r'$\mu \Rightarrow N(p-q)$ = 1600',bbox=dict(facecolor='red', alpha=0.5))
sns.histplot(data=df, x='position',discrete=True,ax=ax2, alpha = 0.6)
plt.title("N = 5000", color= 'r')
# plt.savefig('N=5000')
plt.show()

# %% [markdown]
# ## N = 8000

# %%
from scipy import stats
import random
import matplotlib.pyplot as plt

global x
x = 0 

def random_walk(n):
    x_1 = 0
    # particle postioned at x = 0
    for i in range(n):
        step = round(random.random(),2)
        # steps being randomly assigned either +ve or -ve
        if step <= 0.50:
            x_1 = x
        elif step > 0.50:
            zeta = np.random.choice([-1,1])
            if zeta == -1:
                x_1 = x_1 - 1 
            else:
                x_1 = x_1 + 1
    return (x_1)


number_of_walk = 100
walk_length = 8000
position = []
# length of walk defines how much steps can body take

for i in range(number_of_walk):
    walk = random_walk(walk_length)
#     (walk, "Distance from origin = ", abs(walk))
    position.append(walk)

print(stats.describe(position))
# Out:
# DescribeResult(nobs=100, minmax=(-2, 5), mean=0.02, variance=1.0905050505050506, skewness=1.4042544234766767, kurtosis=5.5380375671913935)

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

df = pd.DataFrame(position, columns=['position'])

fig,ax1 = plt.subplots(dpi=200)
sns.kdeplot(data=df,x='position',linestyle='--',linewidth= 1,ax=ax1, color='blue')

ax2 = ax1.twinx()
# ax1.text(15,0.016,s=r'$\mu \Rightarrow N(p-q)$ = 1600',bbox=dict(facecolor='red', alpha=0.5))
sns.histplot(data=df, x='position',discrete = True, ax=ax2, alpha = 0.6, color = 'teal')
plt.title("N = 8000", color= 'r')
# plt.savefig('N=5000')
plt.show()

# %% [markdown]
# Question!!
#
# How is walker jumping from -1 to straight 1, taking 2 steps at once

# %% [markdown]
# ## N = 15000

# %%
from scipy import stats
import random
import matplotlib.pyplot as plt

global x
x = 0 

def random_walk(n):
    x_1 = 0
    # particle postioned at x = 0
    for i in range(n):
        step = round(random.random(),2)
        # steps being randomly assigned either +ve or -ve
        if step <= 0.50:
            x_1 = x
        else:
            zeta = np.random.choice([-1,1])
            if zeta == -1:
                x_1 = x_1 - 1 
            else:
                x_1 = x_1 + 1
    return (x_1)


number_of_walk = 100
walk_length = 15000
position = []
# length of walk defines how much steps can body take

for i in range(number_of_walk):
    walk = random_walk(walk_length)
#     (walk, "Distance from origin = ", abs(walk))
    position.append(walk)

print(stats.describe(position))
# Out:
# DescribeResult(nobs=100, minmax=(-3, 2), mean=-0.17, variance=0.9506060606060608, skewness=-0.11514802141094686, kurtosis=0.40363234485705934)

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

df = pd.DataFrame(position, columns=['position'])

fig,ax1 = plt.subplots(dpi=200)
sns.kdeplot(data=df,x='position',linestyle='--',linewidth= 1,ax=ax1, color='blue')

ax2 = ax1.twinx()
# ax1.text(15,0.016,s=r'$\mu \Rightarrow N(p-q)$ = 1600',bbox=dict(facecolor='red', alpha=0.5))
sns.histplot(data=df, x='position',discrete=True,ax=ax2, alpha = 0.3, color = 'pink')
plt.title("N = 8000", color= 'r')
# plt.savefig('N=5000')
plt.show()

# %% [markdown]
# ># Asymmetric Walkers

# %% [markdown]
# <h3><font color='Blue'>Symmetric walkers with $r = 0.3$ for constant resetting

# %%
from scipy import stats
import random
import matplotlib.pyplot as plt

global x
x = 0 

def random_walk(n):
    x_1 = 0
    # particle postioned at x = 0
    for i in range(n):
        step = round(random.random(),2)
        # steps being randomly assigned either +ve or -ve
        if step <= 0.30:
            x_1 = x
        else:
            zeta = np.random.choice([-1,1])
            if zeta == -1:
                x_1 = x_1 - 1 
            else:
                x_1 = x_1 + 1
    return (x_1)


number_of_walk = 100
walk_length = 1000
position = []
# length of walk defines how much steps can body take

for i in range(number_of_walk):
    walk = random_walk(walk_length)
#     (walk, "Distance from origin = ", abs(walk))
    position.append(walk)

print(stats.describe(position))
# Out:
# DescribeResult(nobs=100, minmax=(-4, 4), mean=0.14, variance=1.7781818181818179, skewness=0.05047223773337446, kurtosis=1.6681308254444875)

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

df = pd.DataFrame(position, columns=['position'])

fig,ax1 = plt.subplots(dpi=200)
sns.kdeplot(data=df,x='position',linestyle='--',linewidth= 1,ax=ax1, color='blue')

ax2 = ax1.twinx()
# ax1.text(15,0.016,s=r'$\mu \Rightarrow N(p-q)$ = 1600',bbox=dict(facecolor='red', alpha=0.5))
sns.histplot(data=df, x='position',discrete=True,ax=ax2, alpha = 0.3, color = 'pink')
plt.title("N = 1000", color= 'r')
# plt.savefig('N=5000')
plt.show()

# %% [markdown]
# ## N = 5000

# %%
from scipy import stats
import random
import matplotlib.pyplot as plt

global x
x = 0 

def random_walk(n):
    x_1 = 0
    # particle postioned at x = 0
    for i in range(n):
        step = round(random.random(),2)
        # steps being randomly assigned either +ve or -ve
        if step <= 0.30:
            x_1 = x
        else:
            zeta = np.random.choice([-1,1])
            if zeta == -1:
                x_1 = x_1 - 1 
            else:
                x_1 = x_1 + 1
    return (x_1)


number_of_walk = 100
walk_length = 5000
position = []
# length of walk defines how much steps can body take

for i in range(number_of_walk):
    walk = random_walk(walk_length)
#     (walk, "Distance from origin = ", abs(walk))
    position.append(walk)

print(stats.describe(position))
# Out:
# DescribeResult(nobs=100, minmax=(-9, 4), mean=-0.02, variance=2.383434343434344, skewness=-1.5721593739116855, kurtosis=10.983923967793618)

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

df = pd.DataFrame(position, columns=['position'])

fig,ax1 = plt.subplots(dpi=200)
sns.kdeplot(data=df,x='position',linestyle='--',linewidth= 1,ax=ax1, color='blue')

ax2 = ax1.twinx()
# ax1.text(15,0.016,s=r'$\mu \Rightarrow N(p-q)$ = 1600',bbox=dict(facecolor='red', alpha=0.5))
sns.histplot(data=df, x='position',discrete=True,ax=ax2, alpha = 0.3, color = 'yellow')
plt.title("N = 5000", color= 'r')
# plt.savefig('N=5000')
plt.show()

# %% [markdown]
# ## N = 10000

# %%
from scipy import stats
import random
import matplotlib.pyplot as plt

global x
x = 0 

def random_walk(n):
    x_1 = 0
    # particle postioned at x = 0
    for i in range(n):
        step = round(random.random(),2)
        # steps being randomly assigned either +ve or -ve
        if step <= 0.30:
            x_1 = x
        else:
            zeta = np.random.choice([-1,1])
            if zeta == -1:
                x_1 = x_1 - 1 
            else:
                x_1 = x_1 + 1
    return (x_1)


number_of_walk = 100
walk_length = 10000
position = []
# length of walk defines how much steps can body take

for i in range(number_of_walk):
    walk = random_walk(walk_length)
#     (walk, "Distance from origin = ", abs(walk))
    position.append(walk)

print(stats.describe(position))
# Out:
# DescribeResult(nobs=100, minmax=(-4, 8), mean=-0.02, variance=3.2521212121212124, skewness=0.7985422497736342, kurtosis=3.156898528751425)

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

df = pd.DataFrame(position, columns=['position'])

fig,ax1 = plt.subplots(dpi=200)
sns.kdeplot(data=df,x='position',linestyle='--',linewidth= 1,ax=ax1, color='blue')

ax2 = ax1.twinx()
# ax1.text(15,0.016,s=r'$\mu \Rightarrow N(p-q)$ = 1600',bbox=dict(facecolor='red', alpha=0.5))
sns.histplot(data=df, x='position',discrete=True,ax=ax2, alpha = 0.3, color = 'yellow')
plt.title("N = 10000", color= 'r')
# plt.savefig('N=5000')
plt.show()
